# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Si no carga esto en memoria, nada de lo de abajo funciona.
skel_data = pd.read_csv(r'AAX_seminars\Seminar_2\dataset_Seminar2\Train_skelletonpoints.csv', header=None)
labels_data = pd.read_csv(r'AAX_seminars\Seminar_2\dataset_Seminar2\Train_labels.csv', header=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Si no carga esto en memoria, nada de lo de abajo funciona.
# ----> 2 skel_data = pd.read_csv(r'AAX_seminars\Seminar_2\dataset_Seminar2\Train_skelletonpoints.csv', header=None)
#       3 labels_data = pd.read_csv(r'AAX_seminars\Seminar_2\dataset_Seminar2\Train_labels.csv', header=None)
#
# ...

# %%
# ==========================================
# 1. DICCIONARIO DE TRADUCCIÓN (EL SECRETO)
# ==========================================
# Si su dataset tiene otras posturas, cámbielas aquí. 
# Esto convierte la frialdad de las matemáticas en texto humano.
label_map = {
    1: "wave",
    2: "push",
    3: "crouch",
    4: "sitdown",
    5: "bend"
}

conexiones_estandar = [(0,1), (1,2), (2,3), (3,4), (1,5), (5,6), (6,7), 
                       (1,8), (8,9), (9,10), (1,11), (11,12), (12,13), 
                       (0,14), (0,15), (14,16), (15,17), (2, 5), (8, 11)]

# ==========================================
# 2. BÚSQUEDA Y PLOTEO ESTRATÉGICO
# ==========================================
# Buscamos cuántas clases únicas existen realmente en su archivo (saldrán 1, 2, 3, 4, 5)
clases_unicas = np.unique(labels_data.values)
num_clases = len(clases_unicas)

# Creamos una cuadrícula de gráficos: 1 fila, N columnas
fig, axes = plt.subplots(1, num_clases, figsize=(4 * num_clases, 6))

# Si por algún error solo hay 1 clase, convertimos 'axes' en lista para evitar fallos
if num_clases == 1:
    axes = [axes]

# Iteramos sobre cada clase distinta
for i, clase_num in enumerate(clases_unicas):
    # Buscamos el PRIMER índice de la fila donde aparezca esta clase
    idx = np.where(labels_data.values[0] == clase_num)[0][0]
    
    # Extraemos las coordenadas de ese índice
    fila_skel = skel_data.iloc[idx].values
    y_coords = fila_skel[0:18]
    x_coords = fila_skel[18:36]
    
    # Seleccionamos el sub-gráfico correspondiente
    ax = axes[i]
    ax.invert_yaxis()
    ax.scatter(x_coords, y_coords, c='red', s=20, zorder=3)
    
    for inicio, fin in conexiones_estandar:
        ax.plot([x_coords[inicio], x_coords[fin]], 
                [y_coords[inicio], y_coords[fin]], c='blue', linewidth=2, zorder=2)
                
    # Magia del diccionario: usamos .get() para traducir el número al texto
    nombre_pose = label_map.get(clase_num, f"Unknown ({clase_num})")
    
    ax.set_title(f"{nombre_pose}", fontsize=14, fontweight='bold')
    ax.set_aspect('equal')
    ax.grid(True, linestyle='--', alpha=0.5)

# Ajustar el diseño para que no se pisen entre ellos y mostrar
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 22
#      18 # ==========================================
#      19 # 2. BÚSQUEDA Y PLOTEO ESTRATÉGICO
#      20 # ==========================================
#      21 # Buscamos cuántas clases únicas existen realmente en su archivo (saldrán 1, 2, 3, 4, 5)
# ---> 22 clases_unicas = np.unique(labels_data.values)
#      23 num_clases = len(clases_unicas)
#      24
#      25 # Creamos una cuadrícula de gráficos: 1 fila, N columnas
#
# NameError: name 'np' is not defined
